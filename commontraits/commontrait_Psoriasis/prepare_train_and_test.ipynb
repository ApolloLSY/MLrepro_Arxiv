# %%
import gzip


def unzip(input, output):

    input_file = input
    output_file = output

    with gzip.open(input_file, "rb") as f_in:
        with open(output_file, "wb") as f_out:

            f_out.write(f_in.read())

    print("file unzipped and save at", output_file)
# Out:
#   Cell In[2], line 16
#     unzip(""/data/LSY/z_preparing_and_parts/commontrait_Asthma/GSE85566_series_matrix.txt.gz"","/data/LSY/z_preparing_and_parts/commontrait_Asthma/GSE85566_series_matrix.txt")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd



# read matrix
with open(
    "/data/LSY/z_preparing_and_parts/commontrait_Psoriasis/GSE73894_series_matrix.txt", "r"
) as file:
    lines = file.readlines()

# find metadata
first_empty_line_index = lines.index("\n")
table_begin_index = next(
(
        i
        for i, line in enumerate(lines)
        if line.startswith("!series_matrix_table_begin")
    ),
    None,
)
end_index = table_begin_index if table_begin_index is not None else len(lines)
content_before_table = lines[first_empty_line_index:end_index]


# read metadata
metadata_lines = [
    line.strip()[1:].split("\t")
    for line in content_before_table
    if line.startswith("!")
]
metadata_df = pd.DataFrame(metadata_lines).T


metadata_df.columns = metadata_df.iloc[0]
metadata_df = metadata_df.drop(0, axis=0)

metadata_df.dropna(inplace=True)

# %%
print(metadata_df.iloc[:,11])
# Out:
# 1      "disease state: Psoriasis"
# 2      "disease state: Psoriasis"
# 3      "disease state: Psoriasis"
# 4      "disease state: Psoriasis"
# 5      "disease state: Psoriasis"
#                   ...
# 215       "disease state: Normal"
# 216       "disease state: Normal"
# 217       "disease state: Normal"
# 218       "disease state: Normal"
# 219       "disease state: Normal"
# Name: Sample_characteristics_ch1, Length: 219, dtype: object

# %%
# find status
metadata_df["status"] = metadata_df.iloc[:, 11].apply(
    lambda x: 1 if "Psoriasis" in x else 0 if "Normal" in x else None
)
metadata_df = metadata_df.set_index("Sample_geo_accession")

# %%
print(metadata_df)
# Out:
# 0                                                          Sample_title  \
# Sample_geo_accession
# "GSM1905080"          "genomic DNA from uninvolved psoriatic skin sa...
# "GSM1905081"          "genomic DNA from uninvolved psoriatic skin sa...
# "GSM1905082"          "genomic DNA from uninvolved psoriatic skin sa...
# "GSM1905083"          "genomic DNA from uninvolved psoriatic skin sa...
# "GSM1905084"          "genomic DNA from uninvolved psoriatic skin sa...
# ...                                                                 ...
# "GSM1905301"                 "genomic DNA from  normal skin sample 187"
# "GSM1905302"                 "genomic DNA from  normal skin sample 188"
# "GSM1905303"                 "genomic DNA from  normal skin sample 191"
# "GSM1905304"                       "genomic DNA from  replicates UC185"
# "GSM1905305"                       "genomic DNA from  replicates UC188"
#
# 0                               Sample_status Sample_submission_date  \
# Sample_geo_accession
# "GSM1905080"          "Public on Jul 07 2017"          "Oct 09 2015"
# "GSM1905081"          "Public on Jul 07 2017"          "Oct 09 2015"
# "GSM1905082"          "Public on Jul 07 2017"          "Oct 09 2015"
# "GSM1905083"          "Public on Jul 07 2017"          "Oct 09 2015"
# "GSM1905084"          "Public on Jul 07 2017"          "Oct 09 2015"
# ...                                       ...                    ...
# "GSM1905301"          "Public on Jul 07 2017"          "Oct 09 2015"
# "GSM1905302"          "Public on Jul 07 2017"          "Oct 09 2015"
# "GSM1905303"          "Public on Jul 07 2017"          "Oct 09 2015"
# "GSM1905304"          "Public on Jul 07 2017"          "Oct 09 2015"
# "GSM1905305"          "Public on Jul 07 2017"          "Oct 09 2015"
#
# 0                    Sample_last_update_date Sample_type Sample_channel_count  \
# Sample_geo_accession
# "GSM1905080"                   "Jul 07 2017"   "genomic"                  "1"
# "GSM1905081"                   "Jul 07 2017"   "genomic"                  "1"
# "GSM1905082"                   "Jul 07 2017"   "genomic"                  "1"
# "GSM1905083"                   "Jul 07 2017"   "genomic"                  "1"
# "GSM1905084"                   "Jul 07 2017"   "genomic"                  "1"
# ...                                      ...         ...                  ...
# "GSM1905301"                   "Jul 07 2017"   "genomic"                  "1"
# "GSM1905302"                   "Jul 07 2017"   "genomic"                  "1"
# "GSM1905303"                   "Jul 07 2017"   "genomic"                  "1"
# "GSM1905304"                   "Jul 07 2017"   "genomic"                  "1"
# "GSM1905305"                   "Jul 07 2017"   "genomic"                  "1"
#
# 0                                     Sample_source_name_ch1  \
# Sample_geo_accession
# "GSM1905080"          "uninvolved psoriatic skin sample 161"
# "GSM1905081"          "uninvolved psoriatic skin sample 163"
# "GSM1905082"          "uninvolved psoriatic skin sample 164"
# "GSM1905083"          "uninvolved psoriatic skin sample 165"
# "GSM1905084"          "uninvolved psoriatic skin sample 166"
# ...                                                      ...
# "GSM1905301"                        "normal skin sample 187"
# "GSM1905302"                        "normal skin sample 188"
# "GSM1905303"                        "normal skin sample 191"
# "GSM1905304"                              "replicates UC185"
# "GSM1905305"                              "replicates UC188"
#
# 0                    Sample_organism_ch1 Sample_characteristics_ch1  \
# Sample_geo_accession
# "GSM1905080"              "Homo sapiens"             "gender: Male"
# "GSM1905081"              "Homo sapiens"           "gender: Female"
# "GSM1905082"              "Homo sapiens"           "gender: Female"
# "GSM1905083"              "Homo sapiens"             "gender: Male"
# "GSM1905084"              "Homo sapiens"             "gender: Male"
# ...                                  ...                        ...
# "GSM1905301"              "Homo sapiens"             "gender: Male"
# "GSM1905302"              "Homo sapiens"           "gender: Female"
# "GSM1905303"              "Homo sapiens"           "gender: Female"
# "GSM1905304"              "Homo sapiens"             "gender: Male"
# "GSM1905305"              "Homo sapiens"           "gender: Female"
#
# 0                    Sample_characteristics_ch1  ... Sample_contact_name  \
# Sample_geo_accession                             ...
# "GSM1905080"                     "tissue: Skin"  ...     "Fusheng,,Zhou"
# "GSM1905081"                     "tissue: Skin"  ...     "Fusheng,,Zhou"
# "GSM1905082"                     "tissue: Skin"  ...     "Fusheng,,Zhou"
# "GSM1905083"                     "tissue: Skin"  ...     "Fusheng,,Zhou"
# "GSM1905084"                     "tissue: Skin"  ...     "Fusheng,,Zhou"
# ...                                         ...  ...                 ...
# "GSM1905301"                     "tissue: Skin"  ...     "Fusheng,,Zhou"
# "GSM1905302"                     "tissue: Skin"  ...     "Fusheng,,Zhou"
# "GSM1905303"                     "tissue: Skin"  ...     "Fusheng,,Zhou"
# "GSM1905304"                     "tissue: Skin"  ...     "Fusheng,,Zhou"
# "GSM1905305"                     "tissue: Skin"  ...     "Fusheng,,Zhou"
#
# 0                    Sample_contact_email    Sample_contact_institute  \
# Sample_geo_accession
# "GSM1905080"          "biozhoufs@163.com"  "Anhui Medical University"
# "GSM1905081"          "biozhoufs@163.com"  "Anhui Medical University"
# "GSM1905082"          "biozhoufs@163.com"  "Anhui Medical University"
# "GSM1905083"          "biozhoufs@163.com"  "Anhui Medical University"
# "GSM1905084"          "biozhoufs@163.com"  "Anhui Medical University"
# ...                                   ...                         ...
# "GSM1905301"          "biozhoufs@163.com"  "Anhui Medical University"
# "GSM1905302"          "biozhoufs@163.com"  "Anhui Medical University"
# "GSM1905303"          "biozhoufs@163.com"  "Anhui Medical University"
# "GSM1905304"          "biozhoufs@163.com"  "Anhui Medical University"
# "GSM1905305"          "biozhoufs@163.com"  "Anhui Medical University"
#
# 0                                 Sample_contact_address Sample_contact_city  \
# Sample_geo_accession
# "GSM1905080"          "No 96 Meishan Road, Hefei, China"             "Hefei"
# "GSM1905081"          "No 96 Meishan Road, Hefei, China"             "Hefei"
# "GSM1905082"          "No 96 Meishan Road, Hefei, China"             "Hefei"
# "GSM1905083"          "No 96 Meishan Road, Hefei, China"             "Hefei"
# "GSM1905084"          "No 96 Meishan Road, Hefei, China"             "Hefei"
# ...                                                  ...                 ...
# "GSM1905301"          "No 96 Meishan Road, Hefei, China"             "Hefei"
# "GSM1905302"          "No 96 Meishan Road, Hefei, China"             "Hefei"
# "GSM1905303"          "No 96 Meishan Road, Hefei, China"             "Hefei"
# "GSM1905304"          "No 96 Meishan Road, Hefei, China"             "Hefei"
# "GSM1905305"          "No 96 Meishan Road, Hefei, China"             "Hefei"
#
# 0                    Sample_contact_zip/postal_code Sample_contact_country  \
# Sample_geo_accession
# "GSM1905080"                               "230032"                "China"
# "GSM1905081"                               "230032"                "China"
# "GSM1905082"                               "230032"                "China"
# "GSM1905083"                               "230032"                "China"
# "GSM1905084"                               "230032"                "China"
# ...                                             ...                    ...
# "GSM1905301"                               "230032"                "China"
# "GSM1905302"                               "230032"                "China"
# "GSM1905303"                               "230032"                "China"
# "GSM1905304"                               "230032"                "China"
# "GSM1905305"                               "230032"                "China"
#
# 0                    Sample_supplementary_file Sample_data_row_count status
# Sample_geo_accession
# "GSM1905080"                            "NONE"              "485577"      1
# "GSM1905081"                            "NONE"              "485577"      1
# "GSM1905082"                            "NONE"              "485577"      1
# "GSM1905083"                            "NONE"              "485577"      1
# "GSM1905084"                            "NONE"              "485577"      1
# ...                                        ...                   ...    ...
# "GSM1905301"                            "NONE"              "485577"      0
# "GSM1905302"                            "NONE"              "485577"      0
# "GSM1905303"                            "NONE"              "485577"      0
# "GSM1905304"                            "NONE"              "485577"      0
# "GSM1905305"                            "NONE"              "485577"      0
#
# [219 rows x 31 columns]

# %%
metadata_df = metadata_df["status"].apply(pd.to_numeric, errors="coerce")

# %%
metadata_df
# Out:
# Sample_geo_accession
# "GSM1905080"    1
# "GSM1905081"    1
# "GSM1905082"    1
# "GSM1905083"    1
# "GSM1905084"    1
#                ..
# "GSM1905301"    0
# "GSM1905302"    0
# "GSM1905303"    0
# "GSM1905304"    0
# "GSM1905305"    0
# Name: status, Length: 219, dtype: int64

# %%
# read data
data_lines = [line.strip().split() for line in lines if not line.startswith("!")]
data_df = pd.DataFrame(data_lines).T

data_df.columns = data_df.iloc[0]
data_df = data_df.drop(0, axis=0)

data_df = data_df.set_index('"ID_REF"')
data_df = data_df.iloc[:, 1:]
data_df.columns = [col.strip('"') for col in data_df.columns]

data_df = data_df.apply(pd.to_numeric, errors="coerce")

# %%
print(data_df)
# Out:
#               cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  \
# "ID_REF"
# "GSM1905080"     0.29259     0.91727     0.83746     0.33091     0.86586
# "GSM1905081"     0.38943     0.95521     0.86586     0.30256     0.86530
# "GSM1905082"     0.42140     0.93309     0.84979     0.36217     0.90110
# "GSM1905083"     0.30409     0.92671     0.78840     0.30588     0.87750
# "GSM1905084"     0.33408     0.94815     0.87272     0.30801     0.88944
# ...                  ...         ...         ...         ...         ...
# "GSM1905301"     0.26916     0.90001     0.82631     0.28624     0.81995
# "GSM1905302"     0.24330     0.90992     0.84766     0.24782     0.83379
# "GSM1905303"     0.42036     0.93922     0.84657     0.32746     0.87749
# "GSM1905304"     0.30455     0.92300     0.77559     0.23925     0.78473
# "GSM1905305"     0.25864     0.89631     0.79849     0.27985     0.81216
#
#               cg00000289  cg00000292  cg00000321  cg00000363  cg00000622  ...  \
# "ID_REF"                                                                  ...
# "GSM1905080"     0.71010     0.69801     0.41347     0.28877     0.01841  ...
# "GSM1905081"     0.72975     0.74648     0.39950     0.28739     0.03210  ...
# "GSM1905082"     0.71505     0.76129     0.40917     0.30615     0.03387  ...
# "GSM1905083"     0.68079     0.68429     0.38975     0.30620     0.02496  ...
# "GSM1905084"     0.69807     0.72656     0.31711     0.29076     0.02430  ...
# ...                  ...         ...         ...         ...         ...  ...
# "GSM1905301"     0.68826     0.60937     0.29236     0.25216     0.02437  ...
# "GSM1905302"     0.65789     0.74287     0.54345     0.25912     0.02914  ...
# "GSM1905303"     0.73234     0.70445     0.36159     0.27771     0.03166  ...
# "GSM1905304"     0.68277     0.64128     0.29959     0.22150     0.03214  ...
# "GSM1905305"     0.59074     0.72864     0.48402     0.24492     0.03820  ...
#
#               rs7746156  rs798149  rs845016  rs877309  rs9292570  rs9363764  \
# "ID_REF"
# "GSM1905080"    0.95985   0.96438   0.55326   0.04288    0.03309    0.63954
# "GSM1905081"    0.96271   0.55257   0.62031   0.65699    0.04630    0.67409
# "GSM1905082"    0.96650   0.56329   0.62022   0.66730    0.94139    0.67703
# "GSM1905083"    0.57812   0.03889   0.07755   0.63080    0.04512    0.62031
# "GSM1905084"    0.58370   0.96013   0.60768   0.63450    0.50088    0.64435
# ...                 ...       ...       ...       ...        ...        ...
# "GSM1905301"    0.93329   0.43723   0.90524   0.04445    0.93707    0.91622
# "GSM1905302"    0.51665   0.94387   0.87551   0.05334    0.07347    0.08850
# "GSM1905303"    0.61650   0.53986   0.61405   0.07386    0.52790    0.64768
# "GSM1905304"    0.92642   0.93681   0.49104   0.55759    0.05941    0.51664
# "GSM1905305"    0.49658   0.94552   0.89265   0.04703    0.06734    0.07292
#
#               rs939290  rs951295  rs966367  rs9839873
# "ID_REF"
# "GSM1905080"   0.96127   0.93081   0.59745    0.94331
# "GSM1905081"   0.66265   0.52796   0.62154    0.95420
# "GSM1905082"   0.68561   0.53743   0.62930    0.95017
# "GSM1905083"   0.06901   0.53641   0.06783    0.95435
# "GSM1905084"   0.66190   0.54153   0.07392    0.95028
# ...                ...       ...       ...        ...
# "GSM1905301"   0.94279   0.07580   0.08236    0.92791
# "GSM1905302"   0.93656   0.06184   0.08184    0.93933
# "GSM1905303"   0.64071   0.92757   0.12707    0.92904
# "GSM1905304"   0.06741   0.07980   0.48398    0.92077
# "GSM1905305"   0.92042   0.07387   0.06829    0.90446
#
# [219 rows x 485577 columns]

# %%
# merge metadata and data
data_df["status"] = metadata_df
# drop other disease sample
data_df.dropna(subset=["status"], inplace=True)

# %%
data1=data_df

# %%
print(data1)
# Out:
#               cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  \
# "ID_REF"
# "GSM1905080"     0.29259     0.91727     0.83746     0.33091     0.86586
# "GSM1905081"     0.38943     0.95521     0.86586     0.30256     0.86530
# "GSM1905082"     0.42140     0.93309     0.84979     0.36217     0.90110
# "GSM1905083"     0.30409     0.92671     0.78840     0.30588     0.87750
# "GSM1905084"     0.33408     0.94815     0.87272     0.30801     0.88944
# ...                  ...         ...         ...         ...         ...
# "GSM1905301"     0.26916     0.90001     0.82631     0.28624     0.81995
# "GSM1905302"     0.24330     0.90992     0.84766     0.24782     0.83379
# "GSM1905303"     0.42036     0.93922     0.84657     0.32746     0.87749
# "GSM1905304"     0.30455     0.92300     0.77559     0.23925     0.78473
# "GSM1905305"     0.25864     0.89631     0.79849     0.27985     0.81216
#
#               cg00000289  cg00000292  cg00000321  cg00000363  cg00000622  ...  \
# "ID_REF"                                                                  ...
# "GSM1905080"     0.71010     0.69801     0.41347     0.28877     0.01841  ...
# "GSM1905081"     0.72975     0.74648     0.39950     0.28739     0.03210  ...
# "GSM1905082"     0.71505     0.76129     0.40917     0.30615     0.03387  ...
# "GSM1905083"     0.68079     0.68429     0.38975     0.30620     0.02496  ...
# "GSM1905084"     0.69807     0.72656     0.31711     0.29076     0.02430  ...
# ...                  ...         ...         ...         ...         ...  ...
# "GSM1905301"     0.68826     0.60937     0.29236     0.25216     0.02437  ...
# "GSM1905302"     0.65789     0.74287     0.54345     0.25912     0.02914  ...
# "GSM1905303"     0.73234     0.70445     0.36159     0.27771     0.03166  ...
# "GSM1905304"     0.68277     0.64128     0.29959     0.22150     0.03214  ...
# "GSM1905305"     0.59074     0.72864     0.48402     0.24492     0.03820  ...
#
#               rs798149  rs845016  rs877309  rs9292570  rs9363764  rs939290  \
# "ID_REF"
# "GSM1905080"   0.96438   0.55326   0.04288    0.03309    0.63954   0.96127
# "GSM1905081"   0.55257   0.62031   0.65699    0.04630    0.67409   0.66265
# "GSM1905082"   0.56329   0.62022   0.66730    0.94139    0.67703   0.68561
# "GSM1905083"   0.03889   0.07755   0.63080    0.04512    0.62031   0.06901
# "GSM1905084"   0.96013   0.60768   0.63450    0.50088    0.64435   0.66190
# ...                ...       ...       ...        ...        ...       ...
# "GSM1905301"   0.43723   0.90524   0.04445    0.93707    0.91622   0.94279
# "GSM1905302"   0.94387   0.87551   0.05334    0.07347    0.08850   0.93656
# "GSM1905303"   0.53986   0.61405   0.07386    0.52790    0.64768   0.64071
# "GSM1905304"   0.93681   0.49104   0.55759    0.05941    0.51664   0.06741
# "GSM1905305"   0.94552   0.89265   0.04703    0.06734    0.07292   0.92042
#
#               rs951295  rs966367  rs9839873  status
# "ID_REF"
# "GSM1905080"   0.93081   0.59745    0.94331       1
# "GSM1905081"   0.52796   0.62154    0.95420       1
# "GSM1905082"   0.53743   0.62930    0.95017       1
# "GSM1905083"   0.53641   0.06783    0.95435       1
# "GSM1905084"   0.54153   0.07392    0.95028       1
# ...                ...       ...        ...     ...
# "GSM1905301"   0.07580   0.08236    0.92791       0
# "GSM1905302"   0.06184   0.08184    0.93933       0
# "GSM1905303"   0.92757   0.12707    0.92904       0
# "GSM1905304"   0.07980   0.48398    0.92077       0
# "GSM1905305"   0.07387   0.06829    0.90446       0
#
# [219 rows x 485578 columns]

# %%
# read matrix
with open(
    "/data/LSY/z_preparing_and_parts/commontrait_Psoriasis/GSE63315_series_matrix.txt", "r"
) as file:
    lines = file.readlines()

# find metadata
first_empty_line_index = lines.index("\n")
table_begin_index = next(
(
        i
        for i, line in enumerate(lines)
        if line.startswith("!series_matrix_table_begin")
    ),
    None,
)
end_index = table_begin_index if table_begin_index is not None else len(lines)
content_before_table = lines[first_empty_line_index:end_index]


# read metadata
metadata_lines = [
    line.strip()[1:].split("\t")
    for line in content_before_table
    if line.startswith("!")
]
metadata_df = pd.DataFrame(metadata_lines).T


metadata_df.columns = metadata_df.iloc[0]
metadata_df = metadata_df.drop(0, axis=0)

metadata_df.dropna(inplace=True)

# %%
print(metadata_df.iloc[:,10].unique)
# Out:
# <bound method Series.unique of 1      "treatment: PRE-UV"
# 2      "treatment: PRE-UV"
# 3      "treatment: PRE-UV"
# 4      "treatment: PRE-UV"
# 5      "treatment: PRE-UV"
# 6      "treatment: PRE-UV"
# 7      "treatment: PRE-UV"
# 8      "treatment: PRE-UV"
# 9      "treatment: PRE-UV"
# 10     "treatment: PRE-UV"
# 11     "treatment: PRE-UV"
# 12     "treatment: PRE-UV"
# 13     "treatment: MID-UV"
# 14     "treatment: MID-UV"
# 15     "treatment: MID-UV"
# 16     "treatment: MID-UV"
# 17     "treatment: MID-UV"
# 18     "treatment: MID-UV"
# 19     "treatment: MID-UV"
# 20     "treatment: MID-UV"
# 21     "treatment: MID-UV"
# 22     "treatment: MID-UV"
# 23     "treatment: MID-UV"
# 24     "treatment: MID-UV"
# 25    "treatment: POST-UV"
# 26    "treatment: POST-UV"
# 27    "treatment: POST-UV"
# 28    "treatment: POST-UV"
# 29    "treatment: POST-UV"
# 30    "treatment: POST-UV"
# 31    "treatment: POST-UV"
# 32    "treatment: POST-UV"
# 33    "treatment: POST-UV"
# 34    "treatment: POST-UV"
# 35    "treatment: POST-UV"
# 36    "treatment: CONTROL"
# 37    "treatment: CONTROL"
# 38    "treatment: CONTROL"
# 39    "treatment: CONTROL"
# 40    "treatment: CONTROL"
# 41    "treatment: CONTROL"
# 42    "treatment: CONTROL"
# 43    "treatment: CONTROL"
# 44    "treatment: CONTROL"
# 45    "treatment: CONTROL"
# 46    "treatment: CONTROL"
# 47    "treatment: CONTROL"
# Name: Sample_characteristics_ch1, dtype: object>

# %%
# find status
metadata_df["status"] = metadata_df.iloc[:, 10].apply(
    lambda x: 1 if "UV" in x else 0 if "CONTROL" in x else None
)
metadata_df = metadata_df.set_index("Sample_geo_accession")

# %%
metadata_df = metadata_df["status"].apply(pd.to_numeric, errors="coerce")

# %%
print(metadata_df)
# Out:
# Sample_geo_accession
# "GSM1545680"    1
# "GSM1545681"    1
# "GSM1545682"    1
# "GSM1545683"    1
# "GSM1545684"    1
# "GSM1545685"    1
# "GSM1545686"    1
# "GSM1545687"    1
# "GSM1545688"    1
# "GSM1545689"    1
# "GSM1545690"    1
# "GSM1545691"    1
# "GSM1545692"    1
# "GSM1545693"    1
# "GSM1545694"    1
# "GSM1545695"    1
# "GSM1545696"    1
# "GSM1545697"    1
# "GSM1545698"    1
# "GSM1545699"    1
# "GSM1545700"    1
# "GSM1545701"    1
# "GSM1545702"    1
# "GSM1545703"    1
# "GSM1545704"    1
# "GSM1545705"    1
# "GSM1545706"    1
# "GSM1545707"    1
# "GSM1545708"    1
# "GSM1545709"    1
# "GSM1545710"    1
# "GSM1545711"    1
# "GSM1545712"    1
# "GSM1545713"    1
# "GSM1545714"    1
# "GSM1545715"    0
# "GSM1545716"    0
# "GSM1545717"    0
# "GSM1545718"    0
# "GSM1545719"    0
# "GSM1545720"    0
# "GSM1545721"    0
# "GSM1545722"    0
# "GSM1545723"    0
# "GSM1545724"    0
# "GSM1545725"    0
# "GSM1545726"    0
# Name: status, dtype: int64

# %%
# read data
data_lines = [line.strip().split() for line in lines if not line.startswith("!")]
data_df = pd.DataFrame(data_lines).T

data_df.columns = data_df.iloc[0]
data_df = data_df.drop(0, axis=0)

data_df = data_df.set_index('"ID_REF"')
data_df = data_df.iloc[:, 1:]
data_df.columns = [col.strip('"') for col in data_df.columns]

data_df = data_df.apply(pd.to_numeric, errors="coerce")

# %%
def m_to_beta(M):
    return 1 / (1 + 2 ** (-M))

# %%
# data_df = data_df.apply(m_to_beta)

# %%
print(data_df)
# Out:
#               cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  \
# "ID_REF"
# "GSM2934897"    0.151153    0.917041    0.768723    0.298550    0.791547
# "GSM2934898"    0.123610    0.903298    0.789139    0.188680    0.857785
# "GSM2934899"    0.121128    0.906222    0.822538    0.162928    0.838403
# "GSM2934900"    0.123687    0.911727    0.834830    0.168866    0.849524
# "GSM2934901"    0.287819    0.931435    0.745373    0.188126    0.765442
# "GSM2934902"    0.183896    0.905092    0.762814    0.206276    0.896157
# "GSM2934903"    0.151216    0.918186    0.783309    0.119905    0.776661
# "GSM2934904"    0.171083    0.920169    0.800380    0.241709    0.726685
# "GSM2934905"    0.156343    0.914764    0.865551    0.145052    0.886163
# "GSM2934906"    0.170310    0.906953    0.798078    0.212515    0.798399
# "GSM2934913"  0.580476  0.540792  0.697389   0.602276
# "GSM2934914"  0.122516  0.965638  0.667183   0.837349
# "GSM2934915"  0.080807  0.503457  0.469842   0.870262
# "GSM2934916"  0.074740  0.532093  0.504478   0.893371
# "GSM2934917"  0.532136  0.077802  0.853422   0.905936
# "GSM2934918"  0.071373  0.528905  0.848612   0.902188
# "GSM2934919"  0.082408  0.057843  0.477768   0.884074
# "GSM2934920"  0.073555  0.504571  0.479267   0.913984
# "GSM2934921"  0.520220  0.047368  0.403877   0.909393
# "GSM2934922"  0.100033  0.952284  0.434611   0.619451
# "GSM2934923"  0.525535  0.519010  0.488530   0.596136
# "GSM2934924"  0.912159  0.506647  0.473026   0.874024
# "GSM2934925"  0.086734  0.067283  0.820054   0.859188
# "GSM2934926"  0.522871  0.062062  0.831766   0.602899
# "GSM2934927"  0.525684  0.056041  0.875147   0.626160
# "GSM2934928"  0.925284  0.517441  0.098909   0.885938
# "GSM2934929"  0.516199  0.516594  0.095335   0.903391
# "GSM2934930"  0.148114  0.048389  0.365374   0.909526
# "GSM2934931"  0.516412  0.517027  0.465688   0.889418
# "GSM2934932"  0.530160  0.048576  0.432102   0.629807
# "GSM2934933"  0.558956  0.534457  0.511619   0.603689
# "GSM2934934"  0.522335  0.513722  0.503915   0.886891
# "GSM2934935"  0.897473  0.953713  0.811334   0.883060
# "GSM2934936"  0.724949  0.611442  0.193531   0.838194
# "GSM2934937"  0.532413  0.523405  0.820954   0.895075
# "GSM2934938"  0.092716  0.576006  0.803990   0.582178
# "GSM2934939"  0.518164  0.065834  0.831266   0.875075
# "GSM2934940"  0.532143  0.528838  0.456464   0.823476
# "GSM2934941"  0.065197  0.525756  0.857562   0.593228
# "GSM2934942"  0.073708  0.942810  0.502564   0.605588
# "GSM2934943"  0.071798  0.519340  0.501197   0.582896
# "GSM2934944"  0.076800  0.071260  0.465536   0.914792
# "GSM2934945"  0.072370  0.535569  0.485810   0.882084
# "GSM2934946"  0.078151  0.060217  0.799083   0.895280
# "GSM2934947"  0.538729  0.525237  0.489084   0.568708
# "GSM2934948"  0.555853  0.952883  0.719968   0.587609
# "GSM2934949"  0.551781  0.501588  0.782571   0.870112
#
# [53 rows x 485577 columns]

# %%
# merge metadata and data
data_df["status"] = metadata_df
# drop other disease sample
data_df.dropna(subset=["status"], inplace=True)

# %%
concatenated_data = pd.concat([data1, data_df], ignore_index=False, join='outer')

# %%
print(concatenated_data['status'])
# Out:
# "ID_REF"
# "GSM1905080"    1
# "GSM1905081"    1
# "GSM1905082"    1
# "GSM1905083"    1
# "GSM1905084"    1
#                ..
# "GSM1545722"    0
# "GSM1545723"    0
# "GSM1545724"    0
# "GSM1545725"    0
# "GSM1545726"    0
# Name: status, Length: 266, dtype: int64

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(
    concatenated_data, test_size=0.2, random_state=42
)

# save data
train_data.to_csv(
    "/data/LSY/z_preparing_and_parts/commontrait_Psoriasis/data_train.txt",
    index=True,
    header=True,
    sep="\t",
)


# save data
test_data.to_csv(
    "/data/LSY/z_preparing_and_parts/commontrait_Psoriasis/data_test.txt",
    index=True,
    header=True,
    sep="\t",
)
